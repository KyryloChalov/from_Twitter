# %%
from rembg import remove
from PIL import Image

input_path = "20221203_105151.jpg"
output_path = "output.png"
input_ = Image.open(input_path)
print(input_)
print(input_path)
output_ = remove(input_)
output_.save = output_path
print(output_)
print("Done")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2576x1160 at 0x1C280BEAD20>
# 20221203_105151.jpg
# <PIL.Image.Image image mode=RGBA size=2576x1160 at 0x1C2D09CB200>
# Done
