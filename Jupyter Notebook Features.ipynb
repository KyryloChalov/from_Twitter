# %% [markdown]
# https://medium.com/the-pub/10-jupyter-notebook-features-you-didnt-know-they-exist-dc94f448d6f9

# %% [markdown]
# # 10 Jupyter Notebook Features You Didn’t Know they exist
# ##### Go beyond the basics: advanced features to make the most of Jupyter Notebooks

# %%
# %timeit sum(range(1000))
# Out:
# 7.22 μs ± 105 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# <built-in function sum>

# %%
from Ipywidgets import interact

def square(x):
 return x * x

interact(square, x=(0, 10))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from Ipywidgets import interact
#       3 def square(x):
#       4  return x * x
#
# ModuleNotFoundError: No module named 'Ipywidgets'

# %%
# %load_ext autoreload
# %autoreload 2

# %%
print?
# Out:
# Signature: print(*args, sep=' ', end='\n', file=None, flush=False)
# Docstring:
# Prints the values to a stream, or to sys.stdout by default.
#
# sep
#   string inserted between values, default a space.
# end
#   string appended after the last value, default a newline.
# file
#   a file-like object (stream); defaults to the current sys.stdout.
# flush
#   whether to forcibly flush the stream.
# Type:      builtin_function_or_method
